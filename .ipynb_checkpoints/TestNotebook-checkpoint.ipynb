# %%
import pandas as pd

# %%
df = pd.read_csv("boulderweather.csv")

# %%
df
# Out:
#                       DATE  HourlyDewPointTemperature  \
# 0      2022-01-01T00:15:00                       10.0
# 1      2022-01-01T00:35:00                       10.0
# 2      2022-01-01T00:55:00                        9.0
# 3      2022-01-01T01:15:00                        9.0
# 4      2022-01-01T01:35:00                        9.0
# ...                    ...                        ...
# 12604  2022-06-22T23:55:00                       41.0
# 12605  2022-06-22T23:59:00                        NaN
# 12606  2022-06-23T00:15:00                       41.0
# 12607  2022-06-23T00:35:00                       36.0
# 12608  2022-06-23T00:55:00                       37.0
#
#        HourlyDryBulbTemperature  HourlyPrecipitation HourlyPresentWeatherType  \
# 0                          12.0                  NaN                      NaN
# 1                          12.0                  NaN                      NaN
# 2                          12.0                  NaN                      NaN
# ...

# %%
df.shape
# Out:
# (12609, 15)

# %%
df.info
# Out:
# <bound method DataFrame.info of                       DATE  HourlyDewPointTemperature  \
# 0      2022-01-01T00:15:00                       10.0
# 1      2022-01-01T00:35:00                       10.0
# 2      2022-01-01T00:55:00                        9.0
# 3      2022-01-01T01:15:00                        9.0
# 4      2022-01-01T01:35:00                        9.0
# ...                    ...                        ...
# 12604  2022-06-22T23:55:00                       41.0
# 12605  2022-06-22T23:59:00                        NaN
# 12606  2022-06-23T00:15:00                       41.0
# 12607  2022-06-23T00:35:00                       36.0
# 12608  2022-06-23T00:55:00                       37.0
#
#        HourlyDryBulbTemperature  HourlyPrecipitation HourlyPresentWeatherType  \
# 0                          12.0                  NaN                      NaN
# 1                          12.0                  NaN                      NaN
# ...

# %%
df.columns
# Out:
# Index(['DATE', 'HourlyDewPointTemperature', 'HourlyDryBulbTemperature',
#        'HourlyPrecipitation', 'HourlyPresentWeatherType',
#        'HourlyRelativeHumidity', 'HourlySkyConditions',
#        'HourlyStationPressure', 'HourlyVisibility', 'HourlyWetBulbTemperature',
#        'HourlyWindDirection', 'HourlyWindGustSpeed', 'HourlyWindSpeed',
#        'Sunrise', 'Sunset'],
#       dtype='object')

# %%
df.head()
# Out:
#                   DATE  HourlyDewPointTemperature  HourlyDryBulbTemperature  \
# 0  2022-01-01T00:15:00                       10.0                      12.0
# 1  2022-01-01T00:35:00                       10.0                      12.0
# 2  2022-01-01T00:55:00                        9.0                      12.0
# 3  2022-01-01T01:15:00                        9.0                      10.0
# 4  2022-01-01T01:35:00                        9.0                      10.0
#
#    HourlyPrecipitation HourlyPresentWeatherType  HourlyRelativeHumidity  \
# 0                  NaN                      NaN                    92.0
# 1                  NaN                      NaN                    92.0
# 2                  NaN                      NaN                    85.0
# 3                  NaN                      NaN                    92.0
# 4                  NaN                      NaN                    92.0
#
#   HourlySkyConditions  HourlyStationPressure  HourlyVisibility  \
# ...

# %%
df.tail(10)
